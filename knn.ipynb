# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
test.columns
# Out:
# Index(['id', 'brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title'],
#       dtype='object')

# %%
test.head(10)
# Out:
#       id          brand                                              model  \
# 0  54273  Mercedes-Benz                                      E-Class E 350
# 1  54274          Lexus                                        RX 350 Base
# 2  54275  Mercedes-Benz                                      C-Class C 300
# 3  54276           Land  Rover Range Rover 5.0L Supercharged Autobiogra...
# 4  54277            BMW                                       X6 xDrive40i
# 5  54278      Chevrolet                                       Corvette Z06
# 6  54279           Land         Rover Range Rover 3.0L V6 Supercharged HSE
# 7  54280           Land          Rover Range Rover Velar P250 SE R-Dynamic
# 8  54281          Dodge                                         Avenger SE
# 9  54282           Audi                               S4 3.0T Premium Plus
#
#    model_year  milage      fuel_type  \
# 0        2014   73000       Gasoline
# 1        2015  128032       Gasoline
# ...

# %%
train.columns
# Out:
# Index(['id', 'brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
train.head(10)
# Out:
#    id    brand                 model  model_year  milage fuel_type  \
# 0   0     Ford          F-150 Lariat        2018   74349  Gasoline
# 1   1      BMW                 335 i        2007   80000  Gasoline
# 2   2   Jaguar             XF Luxury        2009   91491  Gasoline
# 3   3      BMW          X7 xDrive40i        2022    2437    Hybrid
# 4   4  Pontiac         Firebird Base        2001  111000  Gasoline
# 5   5    Acura            Integra LS        2003  124756  Gasoline
# 6   6     Audi      S5 3.0T Prestige        2014  107380  Gasoline
# 7   7      GMC          Acadia SLT-1        2019   51300  Gasoline
# 8   8     Audi  A3 2.0T Tech Premium        2016   87842  Gasoline
# 9   9    Acura        MDX Technology        2007  152270  Gasoline
#
#                                               engine  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54273 entries, 0 to 54272
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            54273 non-null  int64
#  1   brand         54273 non-null  object
#  2   model         54273 non-null  object
#  3   model_year    54273 non-null  int64
#  4   milage        54273 non-null  int64
#  5   fuel_type     54273 non-null  object
#  6   engine        54273 non-null  object
#  7   transmission  54273 non-null  object
#  8   ext_col       54273 non-null  object
#  9   int_col       54273 non-null  object
#  10  accident      54273 non-null  object
#  11  clean_title   54273 non-null  object
#  12  price         54273 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 5.4+ MB

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
y_train = train['price'].values
X_train = train.drop(['price', 'brand', 'model', 'fuel_type', 'engine', 'transmission', 'ext_col', 'int_col', 'accident', 'clean_title'], axis=1).values

# %%
X_train
# Out:
# array([[    0,  2018, 74349],
#        [    1,  2007, 80000],
#        [    2,  2009, 91491],
#        ...,
#        [54270,  2013, 40989],
#        [54271,  2023,  1518],
#        [54272,  2021, 35000]])

# %%
knn = KNeighborsClassifier(n_neighbors=341)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=341)

# %%
test.shape
# Out:
# (36183, 12)

# %%
X_test = test.drop(['brand', 'model', 'fuel_type', 'engine', 'transmission', 'ext_col', 'int_col', 'accident', 'clean_title'], axis=1)

# %%
X_test.shape
# Out:
# (36183, 3)

# %%
knn.predict(X_test)
# Out:
# /usr/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# array([22000, 15000, 55000, ..., 15000, 26000,  9000])

# %%
sample = pd.read_csv('./sample_submission.csv')

# %%
sample
# Out:
#           id      price
# 0      54273  39218.443
# 1      54274  39218.443
# 2      54275  39218.443
# 3      54276  39218.443
# 4      54277  39218.443
# ...      ...        ...
# 36178  90451  39218.443
# 36179  90452  39218.443
# 36180  90453  39218.443
# 36181  90454  39218.443
# 36182  90455  39218.443
#
# [36183 rows x 2 columns]

# %%
test1 = test.copy(deep=True)

# %%
test1
# Out:
#           id          brand  \
# 0      54273  Mercedes-Benz
# 1      54274          Lexus
# 2      54275  Mercedes-Benz
# 3      54276           Land
# 4      54277            BMW
# ...      ...            ...
# 36178  90451            GMC
# 36179  90452      Chevrolet
# 36180  90453         Toyota
# 36181  90454        Lincoln
# 36182  90455      Chevrolet
#
#                                                    model  model_year  milage  \
# 0                                          E-Class E 350        2014   73000
# 1                                            RX 350 Base        2015  128032
# 2                                          C-Class C 300        2015   51983
# 3      Rover Range Rover 5.0L Supercharged Autobiogra...        2018   29500
# 4                                           X6 xDrive40i        2020   90000
# ...                                                  ...         ...     ...
# 36178                                       Yukon Denali        2019    4500
# ...

# %%
test1['fuel_type'].describe()
# Out:
# count        36183
# unique           7
# top       Gasoline
# freq         33033
# Name: fuel_type, dtype: object

# %%
test1['price'] = knn.predict(X_test)
# Out:
# /usr/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
test1['price']
# Out:
# 0        22000
# 1        15000
# 2        55000
# 3        38000
# 4        12500
#          ...
# 36178    41000
# 36179     7500
# 36180    15000
# 36181    26000
# 36182     9000
# Name: price, Length: 36183, dtype: int64

# %%
sub = test1[['id', 'price']]

# %%
sub
# Out:
#           id  price
# 0      54273  22000
# 1      54274  15000
# 2      54275  55000
# 3      54276  38000
# 4      54277  12500
# ...      ...    ...
# 36178  90451  41000
# 36179  90452   7500
# 36180  90453  15000
# 36181  90454  26000
# 36182  90455   9000
#
# [36183 rows x 2 columns]

# %%
sub.to_csv('submission.csv', index=False)

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36183 entries, 0 to 36182
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      36183 non-null  int64
#  1   price   36183 non-null  int64
# dtypes: int64(2)
# memory usage: 565.5 KB
